   69.72340     1.01325     0.87250     0.89906
   69.70390     1.01325     0.87500     0.90105
   69.68444     1.01325     0.87750     0.90304
   69.66508     1.01325     0.88000     0.90503
   69.64568     1.01325     0.88250     0.90703
   69.62639     1.01325     0.88500     0.90902
   69.60712     1.01325     0.88750     0.91101
   69.58787     1.01325     0.89000     0.91300
   69.56867     1.01325     0.89250     0.91498
   69.54955     1.01325     0.89500     0.91697
   69.53036     1.01325     0.89750     0.91896
   69.51127     1.01325     0.90000     0.92095
   69.49221     1.01325     0.90250     0.92293
   69.47319     1.01325     0.90500     0.92492
   69.45427     1.01325     0.90750     0.92690
   69.43528     1.01325     0.91000     0.92889
   69.41633     1.01325     0.91250     0.93087
   69.39751     1.01325     0.91500     0.93285
   69.37865     1.01325     0.91750     0.93484
   69.35987     1.01325     0.92000     0.93682
   69.34108     1.01325     0.92250     0.93880
   69.32233     1.01325     0.92500     0.94078
   69.30365     1.01325     0.92750     0.94276
   69.28497     1.01325     0.93000     0.94474
   69.26635     1.01325     0.93250     0.94672
   69.24776     1.01325     0.93500     0.94870
   69.22919     1.01325     0.93750     0.95068
   69.21067     1.01325     0.94000     0.95265
   69.19219     1.01325     0.94250     0.95463
   69.17374     1.01325     0.94500     0.95661
   69.15533     1.01325     0.94750     0.95858
   69.13696     1.01325     0.95000     0.96056
   69.11861     1.01325     0.95250     0.96254
   69.10030     1.01325     0.95500     0.96451
   69.08199     1.01325     0.95750     0.96649
   69.06381     1.01325     0.96000     0.96846
   69.04557     1.01325     0.96250     0.97043
   69.02736     1.01325     0.96500     0.97241
   69.00922     1.01325     0.96750     0.97438
   68.99115     1.01325     0.97000     0.97635
   68.97304     1.01325     0.97250     0.97833
   68.95500     1.01325     0.97500     0.98030
   68.93703     1.01325     0.97750     0.98227
   68.91906     1.01325     0.98000     0.98424
   68.90112     1.01325     0.98250     0.98621
   68.88315     1.01325     0.98500     0.98818
   68.86531     1.01325     0.98750     0.99015
   68.84744     1.01325     0.99000     0.99212
   68.82964     1.01325     0.99250     0.99409
   68.81187     1.01325     0.99500     0.99606
   68.79417     1.01325     0.99750     0.99803
   68.77644     1.01325     1.00000     1.00000


""" # Añade todos los datos aquí

# Convertir el bloque de datos en una matriz de numpy
# Primero, convertir el bloque de datos a una lista de líneas, y luego a una lista de números
lineas = datos.strip().split('\n')
datos_limpios = [list(map(float, linea.split())) for linea in lineas]

# Convertir los datos a una matriz numpy
matriz = np.array(datos_limpios)

# Extraer cada columna como un vector (lista)
T = matriz[:, 0]
P = matriz[:, 1]
x1 = matriz[:, 2]
y1 = matriz[:, 3]

# %%
import pandas as pd
from IPython.display import display
# Indices de refraccion , ND en bibliografia
IR_hexano =1.325
IR_ciclohexano =1.427
#En relleno
IR_destilado_anilla =1.3845
IR_Destilado_esfera =1.3867
IR_Residuo_anilla =1.4189
IR_Residuo_esfera =1.4184
tabla_IR = pd.DataFrame({
    'Componente': ['Hexano', 'Ciclohexano', 'Destilado Anilla', 'Destilado Esfera', 'Residuo Anilla', 'Residuo Esfera'],
    'Índice de Refracción': [IR_hexano, IR_ciclohexano, IR_destilado_anilla, IR_Destilado_esfera, IR_Residuo_anilla, IR_Residuo_esfera]
})
display(tabla_IR)
# Calculo XD,XB
XD_anilla = (IR_destilado_anilla - IR_ciclohexano) / (IR_hexano- IR_ciclohexano)
XB_anilla = (IR_Residuo_anilla - IR_ciclohexano) / (IR_hexano- IR_ciclohexano)
XD_esfera = (IR_Destilado_esfera - IR_ciclohexano) / (IR_hexano- IR_ciclohexano)
XB_esfera = (IR_Residuo_esfera - IR_ciclohexano) / (IR_hexano- IR_ciclohexano)
XD2_anilla = 1-XD_anilla
XD2_esfera = 1-XD_esfera
XB2_anilla = 1-XB_anilla
XB2_esfera = 1-XB_esfera
#calculo del vapor 
#componente 1 hexano componente 2 ciclohexano
y1d_anilla = np.interp(XD_anilla,x1,y1)
y1r_anilla = np.interp(XB_anilla,x1,y1)
y2d_anilla = 1-y1d_anilla
y2r_anilla = 1-y1r_anilla
y1r_esfera = np.interp(XB_esfera,x1,y1)
y1d_esfera = np.interp(XD_esfera,x1,y1)
y2r_esfera = 1-y1r_esfera
y2d_esfera = 1-y1d_esfera

#Volatibilidad relativa
#destilado
alpha12d_anilla = (y1d_anilla/XD_anilla)/(y2d_anilla/XD2_anilla)
alpha12r_anilla = (y1r_anilla/XB_anilla)/(y2r_anilla/XB2_anilla)
alpha12d_esfera = (y1d_esfera/XD_esfera)/(y2d_esfera/XD2_esfera)
alpha12r_esfera = (y1r_esfera/XB_esfera)/(y2r_esfera/XB2_esfera)
alpha_media_anilla = np.sqrt(alpha12d_anilla*alpha12r_anilla)
alpha_media_esfera = np.sqrt(alpha12d_esfera*alpha12r_esfera)
# Out:
#          Componente  Índice de Refracción
# 0            Hexano                1.3250
# 1       Ciclohexano                1.4270
# 2  Destilado Anilla                1.3845
# 3  Destilado Esfera                1.3867
# 4    Residuo Anilla                1.4189
# 5    Residuo Esfera                1.4184

# %%
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
# Indices de refraccion , ND en bibliografia
IR_hexano =1.375
IR_ciclohexano =1.427
#En relleno
IR_destilado_anilla =1.3845
IR_Destilado_esfera =1.3867
IR_Residuo_anilla =1.4189
IR_Residuo_esfera =1.4184
resultados = {}
Z = []

for configuracion in ['anilla', 'esfera']:
    if configuracion == 'anilla':
        IR_destilado = IR_destilado_anilla
        IR_Residuo = IR_Residuo_anilla
    else:  # esfera
        IR_destilado = IR_Destilado_esfera
        IR_Residuo = IR_Residuo_esfera
    
    # Calcular XD, XB
    xD = (IR_destilado - IR_ciclohexano) / (IR_hexano - IR_ciclohexano)
    xW = (IR_Residuo - IR_ciclohexano) / (IR_hexano - IR_ciclohexano)
    
    # Interpolar
    y1d = np.interp(xD, x1, y1)
    y1r = np.interp(xW, x1, y1)
    y2d = 1 - y1d
    y2r = 1 - y1r

    # Volatibilidad relativa
    alpha12d = (y1d / xD) / (y2d / (1 - xD))  # Ajusta el cálculo según tus datos
    alpha12r = (y1r / xW) / (y2r / (1 - xW))
    alpha_media = np.sqrt(alpha12d * alpha12r)

    # Almacenar los resultados en el diccionario
    resultados[configuracion] = {
        'xD': xD,
        'xW': xW,
        'y1d': y1d,
        'y1r': y1r,
        'y2d': y2d,
        'y2r': y2r,
        'alpha12d': alpha12d,
        'alpha12r': alpha12r,
        'alpha_media': alpha_media
    }
    


# Continuar con el cálculo de las etapas y la visualización (McCabe-Thiele)
# Inicializar la matriz para las etapas
    s = np.zeros((200, 2))
    s[0, 0] = xD
    s[0, 1] = xD  # Mover horizontalmente para encontrar el punto de equilibrio

    for i in range(1, 200):
        # Movimiento vertical hacia abajo
        s[i, 1] = s[i-1, 0]  # Mover verticalmente a y = x
        if s[i, 1] <= xW:
            s[i, 0] = s[i, 1]  # En la última etapa, y = x = xW
            break
        # Movimiento horizontal a la curva de equilibrio
        s[i, 0] = np.interp(s[i, 1], y1, x1)

    # Limpiar filas con ceros innecesarios
    s = s[~np.all(s == 0, axis=1)]
    s_rows = s.shape[0]

    # Crear un DataFrame para almacenar las etapas
    data = {
        'Etapa': [],
        'x': [],
        'y': [],
        'linea': []
    }

    S = np.zeros((s_rows * 2, 2))
    for i in range(0, s_rows):
        S[i * 2, 0] = s[i, 0]  # Coordenada x de la etapa actual
        S[i * 2, 1] = s[i, 1]  # Coordenada y de la etapa actual
        
        if i < s_rows - 1:
            S[i * 2 + 1, 0] = s[i, 0]  # x permanece igual para el movimiento vertical
            S[i * 2 + 1, 1] = s[i + 1, 1]  # y de la siguiente etapa
        else:
            S[i * 2 + 1, 0] = s[i, 0]
            S[i * 2 + 1, 1] = s[i, 0]  # y = x para la última etapa
            

    for i in range(1, s_rows-1):
        data['Etapa'].append(i)
        data['x'].append(s[i, 0])
        data['y'].append(s[i, 1])
        data['linea'].append('curva de equilibrio')

    df = pd.DataFrame(data)
    Z.append({
        'configuracion': configuracion,
        'S': S
    })

    # Calcular las etapas exactas
    x_ult_etapa = data['x'][-1]
    x_penult = data['x'][-2]
    tolerancia = 1e-5
    if np.abs(x_ult_etapa - x_penult) < tolerancia:
        ultima_etapa_exacta = 0
        Nt_etapas = len(data['Etapa'])  
    else:
        ultima_etapa_exacta = (xW - x_ult_etapa) / (x_penult - x_ult_etapa)
        Nt_etapas = s_rows - 3 + ultima_etapa_exacta

    Etapas_frame = pd.DataFrame({
        'etapas teoricas': [len(data['Etapa'])],
        'etapas exactas': [Nt_etapas]
    })
     # Guardar resultados en la lista Z
    display(Etapas_frame)

    # Graficar el diagrama de McCabe-Thiele
    plt.figure(figsize=(8, 6))
    plt.plot(x1, y1, label='Curva de Equilibrio', color='blue')
    plt.plot([0, 1], [0, 1], color='gray', label='y = x ')
    plt.plot(S[:, 0], S[:, 1], color='red', label=f'Etapas ({len(data["Etapa"])})')

    # Puntos xD y xW
    plt.scatter([xD, xW], [xD, xW], color='green', zorder=5, s=10)

    # Líneas discontinuas desde el eje x hasta los puntos
    plt.plot([xD, xD], [0, xD], color='green', linestyle='--', linewidth=1)
    plt.plot([xW, xW], [0, xW], color='green', linestyle='--', linewidth=1)

    for i in range(len(data['Etapa'])):
        mid_x = (S[i * 2, 0] + S[i * 2 + 2, 0]) / 2
        y = S[i * 2 + 2, 1]
        plt.text(mid_x, y, f'{i+1}', fontsize=10, verticalalignment='bottom', horizontalalignment='left')

    plt.text(xD, -0.015, 'xD', color='green', fontsize=8, verticalalignment='top', horizontalalignment='center')
    plt.text(xW, -0.05, 'xW', color='green', fontsize=8, verticalalignment='top', horizontalalignment='center')

    plt.ylim(0, 1)
    plt.xlabel('Fracción molar del componente ligero en la fase líquida (x)')
    plt.ylabel('Fracción molar del componente ligero en la fase de vapor (y)')
    plt.title(f'Método de McCabe-Thiele a Reflujo Total ({configuracion})')
    plt.legend()
    plt.grid(True)
    plt.show()
    display(df.style.hide(axis='index'))

# Superponer ambas configuraciones en una sola gráfica
plt.figure(figsize=(8, 6))
for datos in Z:
    if datos['configuracion'] == 'anilla':
        plt.plot(datos['S'][:, 0], datos['S'][:, 1], color='c', linestyle='-', label='Etapas Anilla')
    elif datos['configuracion'] == 'esfera':
        plt.plot(datos['S'][:, 0], datos['S'][:, 1], color='m', linestyle='--', label='Etapas Esfera')
plt.plot(x1, y1, label='Curva de Equilibrio', color='r')
plt.plot([0, 1], [0, 1], color='gray', label='y = x ')
plt.xlabel('Fracción molar del componente ligero en la fase líquida (x)')
plt.ylabel('Fracción molar del componente ligero en la fase de vapor (y)')
plt.title('Método de McCabe-Thiele - Comparación Anilla y Esfera')
plt.legend()
plt.grid(True)
plt.show()

# Crear DataFrame para mostrar resultados
resultados_df = pd.DataFrame(resultados).T
display(resultados_df)
# Out:
#    etapas teoricas  etapas exactas
# 0                9         8.10055
# <style type="text/css">
# </style>
# <table id="T_7b5c8">
#   <thead>
#     <tr>
#       <th id="T_7b5c8_level0_col0" class="col_heading level0 col0" >Etapa</th>
#       <th id="T_7b5c8_level0_col1" class="col_heading level0 col1" >x</th>
#       <th id="T_7b5c8_level0_col2" class="col_heading level0 col2" >y</th>
#       <th id="T_7b5c8_level0_col3" class="col_heading level0 col3" >linea</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7b5c8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7b5c8_row0_col1" class="data row0 col1" >0.770929</td>
#       <td id="T_7b5c8_row0_col2" class="data row0 col2" >0.817308</td>
#       <td id="T_7b5c8_row0_col3" class="data row0 col3" >curva de equilibrio</td>
#     </tr>
#     <tr>
#       <td id="T_7b5c8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_7b5c8_row1_col1" class="data row1 col1" >0.714334</td>
# ...
