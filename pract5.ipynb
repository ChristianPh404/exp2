# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# Datos experimentales
Datos = {
    'T,s': [0,443,545,767,895,1013,1100,1211,1312,1412,1545,1630,1704,1793,1880,1944,2013,2142,2225,
            2385,2537,2645,2907,3247,3428,3634,4023,4283,4555,4923,5327,5977],
    'Temp condensador, °C': [23.2,55.9,59.0,60.9,62.4,63.3,64.0,64.2,64.4,64.6,65.0,65.2,65.3,65.3,65.4,
                             65.5,65.6,65.6,65.5,65.4,65.2,65.0,64.9,64.8,65.0,65.1,64.8,65.2,65.1,65.0,63.3,60.7],
    'Temp caldera, °C': [57.5,65.4,67.7,69.5,70.7,71.8,72.9,73.1,73.8,74.2,74.5,74.7,74.8,75.0,75.1,75.2,75.2,
                         75.4,75.7,76.1,76.2,76.6,77.2,78.3,78.8,80.0,81.1,82.4,83.9,85.1,90.4,96.9],
    'V, L': [0.00,0.00,0.50,1.00,1.50,2.00,2.50,3.00,3.50,4.00,4.50,5.00,5.50,6.00,6.50,7.00,7.50,8.00,
             8.50,9.00,9.50,10.00,10.50,11.00,11.50,12.00,12.50,13.00,13.50,14.00,14.50,14.60],
}

df_datos = pd.DataFrame(Datos)
display

# Datos de densidades

densidades_data = {
    'kg/m³': {'Agua': 983.2, 'Hexano': 660.6},
    'kg/L': {'Agua': 0.9832, 'Hexano': 0.6606},
}
df_densidades = pd.DataFrame(densidades_data)

Vhexano_caldera = 14.6 - df_datos['V, L']
mhexano_caldera = Vhexano_caldera * df_densidades.loc['Hexano', 'kg/L']
Vagua_caldera = 12.0
magua_caldera = Vagua_caldera* df_densidades.loc['Agua', 'kg/L']
fraccion_masica_hexano = mhexano_caldera / (mhexano_caldera + magua_caldera)

df_calculos = pd.DataFrame({
    'T,s': df_datos['T,s'],
    'Vhexano_caldera, L': Vhexano_caldera,
    'mhexano_caldera, kg': mhexano_caldera,
    'magua_caldera, kg': magua_caldera,
    'fraccion_masica_hexano': fraccion_masica_hexano,
})
display(df_calculos)
# Mostrar DataFrame de densidades

display(df_densidades)

datos_semillas = {
    'Peso inicial, g': 2000,
    'Riqueza grasa %': 30.48, 
    'aceite recuperado, g': 450
}
df_semillas = pd.DataFrame(datos_semillas, index=['Semillas'])
display(df_semillas)

plt.plot(fraccion_masica_hexano, df_datos['Temp caldera, °C'], 'o')
plt.xlabel('Fracción masica de hexano')
plt.ylabel('Temperatura de la caldera, °C')
plt.title('Temperatura de la caldera vs fracción masica de hexano')
plt.grid()
plt.show()

aceite_pipas = df_semillas['Riqueza grasa %'] * df_semillas['Peso inicial, g'] / 100 # para tener el peso en kg y el porcentaje en fracción
Rendimiento = df_semillas['aceite recuperado, g'] / aceite_pipas
df_semillas['aceite pipas, kg'] = aceite_pipas
df_semillas['Rendimiento'] = Rendimiento.map('{:.2%}'.format)
display(df_semillas)


Vhexano_extraido = np.array(Vhexano_caldera[::-1])

Qhexano_values = []
# Calculamos Qhexano para cada intervalo de tiempo
for i in range(1, len(Vhexano_extraido)):
    delta_V = Vhexano_extraido[i] - Vhexano_extraido[i-1]
    delta_T = df_datos['T,s'][i] - df_datos['T,s'][i-1]
    
    # Evitar división por cero
    if delta_T != 0:
        Qhexano = delta_V / delta_T
    else:
        Qhexano = 0  

    # Añadir Qhexano calculado a la lista
    Qhexano_values.append(Qhexano)


df_Qhexano = pd.DataFrame({
    'T,s': df_datos['T,s'][1:],
    'Qhexano, L/s': Qhexano_values,
})
display(df_Qhexano)

plt.plot(df_datos['T,s'][1:], Qhexano_values, 'o')
plt.xlabel('Qhexano, L/s')
plt.ylabel('Tiempo, s')
plt.title('Qhexano vs tiempo')
plt.grid()
plt.show()
# Out:
#      T,s  Vhexano_caldera, L  mhexano_caldera, kg  magua_caldera, kg  \
# 0      0                14.6              9.64476            11.7984
# 1    443                14.6              9.64476            11.7984
# 2    545                14.1              9.31446            11.7984
# 3    767                13.6              8.98416            11.7984
# 4    895                13.1              8.65386            11.7984
# 5   1013                12.6              8.32356            11.7984
# 6   1100                12.1              7.99326            11.7984
# 7   1211                11.6              7.66296            11.7984
# 8   1312                11.1              7.33266            11.7984
# 9   1412                10.6              7.00236            11.7984
# 10  1545                10.1              6.67206            11.7984
# 11  1630                 9.6              6.34176            11.7984
# 12  1704                 9.1              6.01146            11.7984
# 13  1793                 8.6              5.68116            11.7984
# 14  1880                 8.1              5.35086            11.7984
# 15  1944                 7.6              5.02056            11.7984
# 16  2013                 7.1              4.69026            11.7984
# 17  2142                 6.6              4.35996            11.7984
# 18  2225                 6.1              4.02966            11.7984
# 19  2385                 5.6              3.69936            11.7984
# 20  2537                 5.1              3.36906            11.7984
# 21  2645                 4.6              3.03876            11.7984
# 22  2907                 4.1              2.70846            11.7984
# 23  3247                 3.6              2.37816            11.7984
# 24  3428                 3.1              2.04786            11.7984
# 25  3634                 2.6              1.71756            11.7984
# 26  4023                 2.1              1.38726            11.7984
# 27  4283                 1.6              1.05696            11.7984
# 28  4555                 1.1              0.72666            11.7984
# 29  4923                 0.6              0.39636            11.7984
# 30  5327                 0.1              0.06606            11.7984
# 31  5977                 0.0              0.00000            11.7984
#
#     fraccion_masica_hexano
# 0                 0.449783
# 1                 0.449783
# 2                 0.441175
# 3                 0.432293
# 4                 0.423125
# 5                 0.413656
# 6                 0.403870
# 7                 0.393753
# 8                 0.383286
# 9                 0.372451
# 10                0.361229
# 11                0.349598
# 12                0.337535
# 13                0.325017
# 14                0.312017
# 15                0.298506
# 16                0.284454
# 17                0.269827
# 18                0.254590
# 19                0.238703
# 20                0.222124
# 21                0.204807
# 22                0.186702
# 23                0.167753
# 24                0.147900
# 25                0.127076
# 26                0.105210
# 27                0.082219
# 28                0.058016
# 29                0.032502
# 30                0.005568
# 31                0.000000
#         kg/m³    kg/L
# Agua    983.2  0.9832
# Hexano  660.6  0.6606
#           Peso inicial, g  Riqueza grasa %  aceite recuperado, g
# Semillas             2000            30.48                   450
#           Peso inicial, g  Riqueza grasa %  aceite recuperado, g  \
# Semillas             2000            30.48                   450
#
#           aceite pipas, kg Rendimiento
# Semillas             609.6      73.82%
#      T,s  Qhexano, L/s
# 1    443      0.000226
# 2    545      0.004902
# 3    767      0.002252
# 4    895      0.003906
# 5   1013      0.004237
# 6   1100      0.005747
# 7   1211      0.004505
# 8   1312      0.004950
# 9   1412      0.005000
# 10  1545      0.003759
# 11  1630      0.005882
# 12  1704      0.006757
# 13  1793      0.005618
# 14  1880      0.005747
# 15  1944      0.007812
# 16  2013      0.007246
# 17  2142      0.003876
# 18  2225      0.006024
# 19  2385      0.003125
# 20  2537      0.003289
# 21  2645      0.004630
# 22  2907      0.001908
# 23  3247      0.001471
# 24  3428      0.002762
# 25  3634      0.002427
# 26  4023      0.001285
# 27  4283      0.001923
# 28  4555      0.001838
# 29  4923      0.001359
# 30  5327      0.001238
# 31  5977      0.000000
